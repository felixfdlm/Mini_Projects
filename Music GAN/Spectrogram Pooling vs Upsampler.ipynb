# %%
import librosa
import tensorflow as tf
import os
from keras import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Reshape, UpSampling2D
from keras import layers
import keras
import numpy as np
import matplotlib.pyplot as plt
import time
import soundfile
from IPython.display import Audio as IAudio

timestep = 2**9
sr = 2**14

# %%
cross_entropy_artist = tf.keras.losses.BinaryCrossentropy(from_logits=True)
cross_entropy_critic = tf.keras.losses.BinaryCrossentropy(from_logits=False)

def critic_loss(real_output, fake_output):
    real_loss = cross_entropy_critic(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy_critic(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def artist_loss(fake_output):
    return cross_entropy_artist(tf.ones_like(fake_output),fake_output)

# %%
artist_optimizer = tf.keras.optimizers.Adam(1e-5)
critic_optimizer = tf.keras.optimizers.Adam(1e-5)

# %%
critic = Sequential()

critic.add(Conv2D(2**3, 2**3, activation='relu',padding='same',input_shape=(1025,1292,2)))
critic.add(MaxPooling2D(pool_size=(25,4*17)))
critic.add(Conv2D(2**4, 2**3, activation='relu',padding='same'))
critic.add(Conv2D(2, 2**4, activation='relu',padding='same'))
critic.add(Flatten())
critic.add(Dense(2**7,activation='relu'))
critic.add(Dense(2**7,activation='relu'))
critic.add(Dense(1,activation='sigmoid'))

artist = Sequential()
artist.add(Dense(2**7,activation='relu',input_shape=(41*19,)))
artist.add(Dense(2**7,activation='relu'))
artist.add(Dense(41*19,activation='relu'))
artist.add(Reshape((41,19,1)))
artist.add(Conv2D(2**2,kernel_size=(7,3),padding='same',activation='relu'))
artist.add(UpSampling2D((5,4)))
artist.add(Conv2D(2**2,kernel_size=(10,6),padding='same',activation='relu'))
artist.add(UpSampling2D((5,17)))
artist.add(Conv2D(2**2,kernel_size=(10,6),padding='same',activation='relu'))
artist.add(Conv2D(2**2,kernel_size=2**4,padding='same',activation='relu'))
artist.add(Conv2D(2,kernel_size=2**4,padding='same'))

# %%
critic.load_weights('spect-critic')
artist.load_weights('spect-artist')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\anaconda3\envs\Spoti\lib\site-packages\tensorflow\python\training\py_checkpoint_reader.py in NewCheckpointReader(filepattern)
#      94   try:
# ---> 95     return CheckpointReader(compat.as_bytes(filepattern))
#      96   # TODO(b/143319754): Remove the RuntimeError casting logic once we resolve the
#
# RuntimeError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for spect-critic
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6044/591307131.py in <module>
# ----> 1 critic.load_weights('spect-critic')
#       2 artist.load_weights('spect-artist')
#
# ~\anaconda3\envs\Spoti\lib\site-packages\tensorflow\python\keras\engine\training.py in load_weights(self, filepath, by_name, skip_mismatch, options)
#    2174     else:
#    2175       try:
# -> 2176         py_checkpoint_reader.NewCheckpointReader(filepath)
#    2177         save_format = 'tf'
#    2178       except errors_impl.DataLossError:
#
# ~\anaconda3\envs\Spoti\lib\site-packages\tensorflow\python\training\py_checkpoint_reader.py in NewCheckpointReader(filepattern)
#      97   # issue with throwing python exceptions from C++.
#      98   except RuntimeError as e:
# ---> 99     error_translator(e)
#
# ~\anaconda3\envs\Spoti\lib\site-packages\tensorflow\python\training\py_checkpoint_reader.py in error_translator(e)
#      33       'Failed to find any '
#      34       'matching files for') in error_message:
# ---> 35     raise errors_impl.NotFoundError(None, None, error_message)
#      36   elif 'Sliced checkpoints are not supported' in error_message or (
#      37       'Data type '
#
# NotFoundError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for spect-critic

# %%
def spec_2_song(spectrogram):
    empty_spectrogram = np.zeros_like(spectrogram[:,:,0],dtype = np.complex64)
    empty_spectrogram.real = spectrogram[:,:,0]
    empty_spectrogram.imag = spectrogram[:,:,1]
    track = librosa.istft(empty_spectrogram)
    return track

def create_Spectrogram(track):
    spectrogram_complex = librosa.stft(track)
    real = spectrogram_complex.real.reshape(spectrogram_complex.shape+(1,))
    imaginary = spectrogram_complex.imag.reshape(spectrogram_complex.shape+(1,))
    spectrogram = np.concatenate((real,imaginary),axis = 2)
    return spectrogram

# %%
@tf.function
def train_step(batch_size=1):
    
    addresses = [os.path.join('spectrograms',trackid) for trackid in os.listdir('spectrograms/')]
    random_indexes = np.random.randint(0,len(addresses),batch_size)
    spectrograms = np.array([np.load(addresses[i]) for i in random_indexes])
#     spectrograms = tf.convert_to_tensor(spectrograms)
    
    noise = np.random.normal(size = (batch_size,41*19))

    with tf.GradientTape() as art_tape, tf.GradientTape() as crit_tape:
        
        fake_output = artist(noise)
        
        
        real_preds = critic(spectrograms)
        fake_preds = critic(fake_output)
        
        art_loss = artist_loss(fake_preds)
        crit_loss = critic_loss(real_preds,fake_preds)

    gradients_of_artist = art_tape.gradient(art_loss, artist.trainable_variables)
    gradients_of_critic = crit_tape.gradient(crit_loss, critic.trainable_variables)

    artist_optimizer.apply_gradients(zip(gradients_of_artist, artist.trainable_variables))
    critic_optimizer.apply_gradients(zip(gradients_of_critic, critic.trainable_variables))

# %%
artist.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 128)               99840
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_5 (Dense)              (None, 779)               100491
# _________________________________________________________________
# reshape (Reshape)            (None, 41, 19, 1)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 41, 19, 4)         88
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 205, 76, 4)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 205, 76, 4)        964
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 1025, 1292, 4)     0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 1025, 1292, 4)     964
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 1025, 1292, 4)     4100
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 1025, 1292, 2)     2050
# =================================================================
# Total params: 225,009
# Trainable params: 225,009
# Non-trainable params: 0
# _________________________________________________________________

# %%
for i in range(501):
    start_time = time.time()
    train_step(batch_size=2)
    print('Iteration '+ str(i) + ' - Time elapsed: ' + str(time.time()-start_time))
    
    if i%50 == 0:
        
        print('Current Iteration: ' + str(i))
        
        track_path = 'tracks/' + os.listdir('tracks')[np.random.randint(0,len(os.listdir('tracks')))]
        print(track_path)
        real_track = librosa.load(track_path)[0]
        real_spectrogram = create_Spectrogram(real_track)
                
        noise = np.random.randn(1,41*19)
        fake_spectrogram = artist.predict(noise)
        
        white_noise = np.random.randn(1,1025,1292,2)
        
        real_pred = critic.predict(real_spectrogram.reshape((1,)+ real_spectrogram.shape))
        fake_pred = critic.predict(fake_spectrogram)
        noise_pred = critic.predict(white_noise)

        artist.save_weights('spect-artist')
        critic.save_weights('spect-critic')     
        
        
        print('Real Track: ' + str(real_pred))
        print('Fake Track: ' + str(fake_pred))
        print('White Noise: ' + str(noise_pred))
        
        fake_track = spec_2_song(fake_spectrogram[0])
        
        soundfile.write('test-' + str(i) + '.wav',np.array(fake_track).reshape(-1),samplerate=22033,format='WAV')

        print(time.ctime())
        time.sleep(1)
# Out:
# Iteration 0 - Time elapsed: 0.023987531661987305
# Current Iteration: 0
# tracks/Reach out for the Light (Live) - Recorded @ Wacken & Masters of Rock.mp3
# Real Track: [[0.9895454]]
# Fake Track: [[0.49666876]]
# White Noise: [[0.46391544]]
# Mon Jan 31 22:58:54 2022
# Iteration 1 - Time elapsed: 0.004998445510864258
# Iteration 2 - Time elapsed: 0.005003213882446289
# Iteration 3 - Time elapsed: 0.004997730255126953
# Iteration 4 - Time elapsed: 0.005997419357299805
# Iteration 5 - Time elapsed: 0.004998445510864258
# Iteration 6 - Time elapsed: 0.004998445510864258
# Iteration 7 - Time elapsed: 0.005998134613037109
# Iteration 8 - Time elapsed: 0.004997968673706055
# Iteration 9 - Time elapsed: 0.004998683929443359
# Iteration 10 - Time elapsed: 0.004997968673706055
# Iteration 11 - Time elapsed: 0.004998445510864258
# Iteration 12 - Time elapsed: 0.40742039680480957
# Iteration 13 - Time elapsed: 1.1443359851837158
# Iteration 14 - Time elapsed: 1.158754825592041
# Iteration 15 - Time elapsed: 1.139695644378662
# Iteration 16 - Time elapsed: 1.154041051864624
# Iteration 17 - Time elapsed: 1.146515130996704
# Iteration 18 - Time elapsed: 1.1536023616790771
# Iteration 19 - Time elapsed: 1.1584246158599854
# Iteration 20 - Time elapsed: 1.1543433666229248
# Iteration 21 - Time elapsed: 1.1262309551239014
# Iteration 22 - Time elapsed: 1.1672372817993164
# Iteration 23 - Time elapsed: 1.1504430770874023
# Iteration 24 - Time elapsed: 1.1565465927124023
# Iteration 25 - Time elapsed: 1.149400234222412
# Iteration 26 - Time elapsed: 1.1388413906097412
# Iteration 27 - Time elapsed: 1.1546177864074707
# Iteration 28 - Time elapsed: 1.1535289287567139
# Iteration 29 - Time elapsed: 1.1384434700012207
# Iteration 30 - Time elapsed: 1.153440237045288
# Iteration 31 - Time elapsed: 1.150935411453247
# Iteration 32 - Time elapsed: 1.147892713546753
# Iteration 33 - Time elapsed: 1.1540822982788086
# Iteration 34 - Time elapsed: 1.1429214477539062
# Iteration 35 - Time elapsed: 1.1560132503509521
# Iteration 36 - Time elapsed: 1.1445951461791992
# Iteration 37 - Time elapsed: 1.143495798110962
# Iteration 38 - Time elapsed: 1.1557354927062988
# Iteration 39 - Time elapsed: 1.1529045104980469
# Iteration 40 - Time elapsed: 1.153883695602417
# Iteration 41 - Time elapsed: 1.1522488594055176
# Iteration 42 - Time elapsed: 1.1426711082458496
# Iteration 43 - Time elapsed: 1.1551597118377686
# Iteration 44 - Time elapsed: 1.1392600536346436
# Iteration 45 - Time elapsed: 1.1471009254455566
# Iteration 46 - Time elapsed: 1.1605298519134521
# Iteration 47 - Time elapsed: 1.1389987468719482
# Iteration 48 - Time elapsed: 1.1514995098114014
# Iteration 49 - Time elapsed: 1.1593420505523682
# Iteration 50 - Time elapsed: 1.1366093158721924
# Current Iteration: 50
# tracks/Give Me the Night - 2018 Mix.mp3
# Real Track: [[0.9988017]]
# Fake Track: [[0.49234965]]
# White Noise: [[0.39789647]]
# Mon Jan 31 22:59:54 2022
# Iteration 51 - Time elapsed: 0.005999088287353516
# Iteration 52 - Time elapsed: 0.0049974918365478516
# Iteration 53 - Time elapsed: 0.005999088287353516
# Iteration 54 - Time elapsed: 0.004997730255126953
# Iteration 55 - Time elapsed: 0.004997968673706055
# Iteration 56 - Time elapsed: 0.004998922348022461
# Iteration 57 - Time elapsed: 0.004998207092285156
# Iteration 58 - Time elapsed: 0.004998207092285156
# Iteration 59 - Time elapsed: 0.004998207092285156
# Iteration 60 - Time elapsed: 0.004998445510864258
# Iteration 61 - Time elapsed: 0.004998683929443359
# Iteration 62 - Time elapsed: 0.4155302047729492
# Iteration 63 - Time elapsed: 1.159271478652954
# Iteration 64 - Time elapsed: 1.1431007385253906
# Iteration 65 - Time elapsed: 1.1640214920043945
# Iteration 66 - Time elapsed: 1.1568360328674316
# Iteration 67 - Time elapsed: 1.1574807167053223
# Iteration 68 - Time elapsed: 1.154494047164917
# Iteration 69 - Time elapsed: 1.1571927070617676
# Iteration 70 - Time elapsed: 1.1538848876953125
# Iteration 71 - Time elapsed: 1.1403090953826904
# Iteration 72 - Time elapsed: 1.1601495742797852
# Iteration 73 - Time elapsed: 1.1497795581817627
# Iteration 74 - Time elapsed: 1.153604507446289
# Iteration 75 - Time elapsed: 1.1546003818511963
# Iteration 76 - Time elapsed: 1.156317949295044
# Iteration 77 - Time elapsed: 1.1655466556549072
# Iteration 78 - Time elapsed: 1.1538887023925781
# Iteration 79 - Time elapsed: 1.1600830554962158
# Iteration 80 - Time elapsed: 1.1484429836273193
# Iteration 81 - Time elapsed: 1.1589422225952148
# Iteration 82 - Time elapsed: 1.160623550415039
# Iteration 83 - Time elapsed: 1.1489663124084473
# Iteration 84 - Time elapsed: 1.162003993988037
# Iteration 85 - Time elapsed: 1.1473393440246582
# Iteration 86 - Time elapsed: 1.1684985160827637
# Iteration 87 - Time elapsed: 1.1575679779052734
# Iteration 88 - Time elapsed: 1.1452229022979736
# Iteration 89 - Time elapsed: 1.15714693069458
# Iteration 90 - Time elapsed: 1.1635138988494873
# Iteration 91 - Time elapsed: 1.1609528064727783
# Iteration 92 - Time elapsed: 1.1612257957458496
# Iteration 93 - Time elapsed: 1.1628541946411133
# Iteration 94 - Time elapsed: 1.1545426845550537
# Iteration 95 - Time elapsed: 1.1679723262786865
# Iteration 96 - Time elapsed: 1.149045705795288
# Iteration 97 - Time elapsed: 1.1760356426239014
# Iteration 98 - Time elapsed: 1.1515600681304932
# Iteration 99 - Time elapsed: 1.159604549407959
# Iteration 100 - Time elapsed: 1.1562473773956299
# Current Iteration: 100
# tracks/Scales of Justice - The Wicked Symphony.mp3
# Real Track: [[0.9993767]]
# Fake Track: [[0.48530754]]
# White Noise: [[0.09876888]]
# Mon Jan 31 23:00:53 2022
# Iteration 101 - Time elapsed: 0.004998207092285156
# Iteration 102 - Time elapsed: 0.004998207092285156
# Iteration 103 - Time elapsed: 0.004998922348022461
# Iteration 104 - Time elapsed: 0.004997730255126953
# Iteration 105 - Time elapsed: 0.004998683929443359
# Iteration 106 - Time elapsed: 0.004998207092285156
# Iteration 107 - Time elapsed: 0.004998445510864258
# Iteration 108 - Time elapsed: 0.004998922348022461
# Iteration 109 - Time elapsed: 0.004997968673706055
# Iteration 110 - Time elapsed: 0.003998517990112305
# Iteration 111 - Time elapsed: 0.003998517990112305
# Iteration 112 - Time elapsed: 0.4156227111816406
# Iteration 113 - Time elapsed: 1.159632921218872
# Iteration 114 - Time elapsed: 1.1592869758605957
# Iteration 115 - Time elapsed: 1.1401164531707764
# Iteration 116 - Time elapsed: 1.1560924053192139
# Iteration 117 - Time elapsed: 1.154710292816162
# Iteration 118 - Time elapsed: 1.1572623252868652
# Iteration 119 - Time elapsed: 1.1560556888580322
# Iteration 120 - Time elapsed: 1.1558778285980225
# Iteration 121 - Time elapsed: 1.1550979614257812
# Iteration 122 - Time elapsed: 1.156928300857544
# Iteration 123 - Time elapsed: 1.149665355682373
# Iteration 124 - Time elapsed: 1.1581995487213135
# Iteration 125 - Time elapsed: 1.1532294750213623
# Iteration 126 - Time elapsed: 1.15494966506958
# Iteration 127 - Time elapsed: 1.159400224685669
# Iteration 128 - Time elapsed: 1.1533193588256836
# Iteration 129 - Time elapsed: 1.1533432006835938
# Iteration 130 - Time elapsed: 1.1539223194122314
# Iteration 131 - Time elapsed: 1.1590981483459473
# Iteration 132 - Time elapsed: 1.1555671691894531
# Iteration 133 - Time elapsed: 1.157069444656372
# Iteration 134 - Time elapsed: 1.1567316055297852
# Iteration 135 - Time elapsed: 1.155456781387329
# Iteration 136 - Time elapsed: 1.1522438526153564
# Iteration 137 - Time elapsed: 1.1564197540283203
# Iteration 138 - Time elapsed: 1.1464200019836426
# Iteration 139 - Time elapsed: 1.167844533920288
# Iteration 140 - Time elapsed: 1.1752831935882568
# Iteration 141 - Time elapsed: 1.1592457294464111
# Iteration 142 - Time elapsed: 1.1498277187347412
# Iteration 143 - Time elapsed: 1.1525752544403076
# Iteration 144 - Time elapsed: 1.1610145568847656
# Iteration 145 - Time elapsed: 1.165966272354126
# Iteration 146 - Time elapsed: 1.139789342880249
# Iteration 147 - Time elapsed: 1.1555683612823486
# Iteration 148 - Time elapsed: 1.1669204235076904
# Iteration 149 - Time elapsed: 1.1607434749603271
# Iteration 150 - Time elapsed: 1.1507761478424072
# Current Iteration: 150
# tracks/ブレイク・オブ・ドーン.mp3
# Real Track: [[0.99924636]]
# Fake Track: [[0.4742016]]
# White Noise: [[0.00070973]]
# Mon Jan 31 23:01:52 2022
# Iteration 151 - Time elapsed: 0.0049991607666015625
# Iteration 152 - Time elapsed: 0.004998683929443359
# Iteration 153 - Time elapsed: 0.004998207092285156
# Iteration 154 - Time elapsed: 0.006997585296630859
# Iteration 155 - Time elapsed: 0.005998134613037109
# Iteration 156 - Time elapsed: 0.004998683929443359
# Iteration 157 - Time elapsed: 0.004998207092285156
# Iteration 158 - Time elapsed: 0.004998207092285156
# Iteration 159 - Time elapsed: 0.004999399185180664
# Iteration 160 - Time elapsed: 0.0069963932037353516
# Iteration 161 - Time elapsed: 0.006997346878051758
# Iteration 162 - Time elapsed: 0.3990814685821533
# Iteration 163 - Time elapsed: 1.1613619327545166
# Iteration 164 - Time elapsed: 1.1573617458343506
# Iteration 165 - Time elapsed: 1.1606919765472412
# Iteration 166 - Time elapsed: 1.1570916175842285
# Iteration 167 - Time elapsed: 1.143768548965454
# Iteration 168 - Time elapsed: 1.171475887298584
# Iteration 169 - Time elapsed: 1.1404058933258057
# Iteration 170 - Time elapsed: 1.154973030090332
# Iteration 171 - Time elapsed: 1.156597375869751
# Iteration 172 - Time elapsed: 1.157489538192749
# Iteration 173 - Time elapsed: 1.152726173400879
# Iteration 174 - Time elapsed: 1.1680676937103271
# Iteration 175 - Time elapsed: 1.1544272899627686
# Iteration 176 - Time elapsed: 1.1530787944793701
# Iteration 177 - Time elapsed: 1.1559042930603027
# Iteration 178 - Time elapsed: 1.1546626091003418
# Iteration 179 - Time elapsed: 1.1562139987945557
# Iteration 180 - Time elapsed: 1.1513216495513916
# Iteration 181 - Time elapsed: 1.1548478603363037
# Iteration 182 - Time elapsed: 1.1554811000823975
# Iteration 183 - Time elapsed: 1.1534538269042969
# Iteration 184 - Time elapsed: 1.1537199020385742
# Iteration 185 - Time elapsed: 1.168114185333252
# Iteration 186 - Time elapsed: 1.144892930984497
# Iteration 187 - Time elapsed: 1.1692008972167969
# Iteration 188 - Time elapsed: 1.15303373336792
# Iteration 189 - Time elapsed: 1.155555248260498
# Iteration 190 - Time elapsed: 1.1532552242279053
# Iteration 191 - Time elapsed: 1.1554806232452393
# Iteration 192 - Time elapsed: 1.1544296741485596
# Iteration 193 - Time elapsed: 1.1504037380218506
# Iteration 194 - Time elapsed: 1.1630773544311523
# Iteration 195 - Time elapsed: 1.1454904079437256
# Iteration 196 - Time elapsed: 1.167245626449585
# Iteration 197 - Time elapsed: 1.1516056060791016
# Iteration 198 - Time elapsed: 1.1537094116210938
# Iteration 199 - Time elapsed: 1.1573278903961182
# Iteration 200 - Time elapsed: 1.1547563076019287
# Current Iteration: 200
# tracks/Satanic Curses.mp3
# Real Track: [[0.16123752]]
# Fake Track: [[0.4542881]]
# White Noise: [[1.0169853e-06]]
# Mon Jan 31 23:02:52 2022
# Iteration 201 - Time elapsed: 0.0049877166748046875
# Iteration 202 - Time elapsed: 0.005997657775878906
# Iteration 203 - Time elapsed: 0.004998683929443359
# Iteration 204 - Time elapsed: 0.005998373031616211
# Iteration 205 - Time elapsed: 0.004998207092285156
# Iteration 206 - Time elapsed: 0.004998445510864258
# Iteration 207 - Time elapsed: 0.005997180938720703
# Iteration 208 - Time elapsed: 0.004998683929443359
# Iteration 209 - Time elapsed: 0.004998922348022461
# Iteration 210 - Time elapsed: 0.004998922348022461
# Iteration 211 - Time elapsed: 0.004997968673706055
# Iteration 212 - Time elapsed: 0.4071035385131836
# Iteration 213 - Time elapsed: 1.152376413345337
# Iteration 214 - Time elapsed: 1.1573586463928223
# Iteration 215 - Time elapsed: 1.1701147556304932
# Iteration 216 - Time elapsed: 1.149519443511963
# Iteration 217 - Time elapsed: 1.1563377380371094
# Iteration 218 - Time elapsed: 1.15567946434021
# Iteration 219 - Time elapsed: 1.146700143814087
# Iteration 220 - Time elapsed: 1.1586854457855225
# Iteration 221 - Time elapsed: 1.1562249660491943
# Iteration 222 - Time elapsed: 1.1537177562713623
# Iteration 223 - Time elapsed: 1.15132474899292
# Iteration 224 - Time elapsed: 1.1508595943450928
# Iteration 225 - Time elapsed: 1.1577184200286865
# Iteration 226 - Time elapsed: 1.1672289371490479
# Iteration 227 - Time elapsed: 1.1535859107971191
# Iteration 228 - Time elapsed: 1.1531298160552979
# Iteration 229 - Time elapsed: 1.1559498310089111
# Iteration 230 - Time elapsed: 1.1549794673919678
# Iteration 231 - Time elapsed: 1.1537892818450928
# Iteration 232 - Time elapsed: 1.1543703079223633
# Iteration 233 - Time elapsed: 1.1495449542999268
# Iteration 234 - Time elapsed: 1.1634948253631592
# Iteration 235 - Time elapsed: 1.1539740562438965
# Iteration 236 - Time elapsed: 1.1529877185821533
# Iteration 237 - Time elapsed: 1.1574456691741943
# Iteration 238 - Time elapsed: 1.1551103591918945
# Iteration 239 - Time elapsed: 1.1489524841308594
# Iteration 240 - Time elapsed: 1.1546168327331543
# Iteration 241 - Time elapsed: 1.149327278137207
# Iteration 242 - Time elapsed: 1.1680192947387695
# Iteration 243 - Time elapsed: 1.1407825946807861
# Iteration 244 - Time elapsed: 1.1548583507537842
# Iteration 245 - Time elapsed: 1.1592440605163574
# Iteration 246 - Time elapsed: 1.1568048000335693
# Iteration 247 - Time elapsed: 1.1573657989501953
# Iteration 248 - Time elapsed: 1.1457641124725342
# Iteration 249 - Time elapsed: 1.1562831401824951
# Iteration 250 - Time elapsed: 1.1549229621887207
# Current Iteration: 250
# tracks/Holding On.mp3
# Real Track: [[0.02406604]]
# Fake Track: [[0.4064849]]
# White Noise: [[2.9820246e-10]]
# Mon Jan 31 23:03:51 2022
# Iteration 251 - Time elapsed: 0.003990888595581055
# Iteration 252 - Time elapsed: 0.005997419357299805
# Iteration 253 - Time elapsed: 0.005997896194458008
# Iteration 254 - Time elapsed: 0.005998134613037109
# Iteration 255 - Time elapsed: 0.004998683929443359
# Iteration 256 - Time elapsed: 0.00499725341796875
# Iteration 257 - Time elapsed: 0.004999399185180664
# Iteration 258 - Time elapsed: 0.004998445510864258
# Iteration 259 - Time elapsed: 0.004998683929443359
# Iteration 260 - Time elapsed: 0.005997657775878906
# Iteration 261 - Time elapsed: 0.005999326705932617
# Iteration 262 - Time elapsed: 0.4046323299407959
# Iteration 263 - Time elapsed: 1.1548004150390625
# Iteration 264 - Time elapsed: 1.1645004749298096
# Iteration 265 - Time elapsed: 1.1517438888549805
# Iteration 266 - Time elapsed: 1.153101921081543
# Iteration 267 - Time elapsed: 1.1545214653015137
# Iteration 268 - Time elapsed: 1.1580147743225098
# Iteration 269 - Time elapsed: 1.1588807106018066
# Iteration 270 - Time elapsed: 1.156121015548706
# Iteration 271 - Time elapsed: 1.1551353931427002
# Iteration 272 - Time elapsed: 1.1495006084442139
# Iteration 273 - Time elapsed: 1.1584107875823975
# Iteration 274 - Time elapsed: 1.1523818969726562
# Iteration 275 - Time elapsed: 1.1542344093322754
# Iteration 276 - Time elapsed: 1.1520264148712158
# Iteration 277 - Time elapsed: 1.1568992137908936
# Iteration 278 - Time elapsed: 1.1521868705749512
# Iteration 279 - Time elapsed: 1.1527800559997559
# Iteration 280 - Time elapsed: 1.1490581035614014
# Iteration 281 - Time elapsed: 1.1615777015686035
# Iteration 282 - Time elapsed: 1.1736059188842773
# Iteration 283 - Time elapsed: 1.163667917251587
# Iteration 284 - Time elapsed: 1.1535212993621826
# Iteration 285 - Time elapsed: 1.1576895713806152
# Iteration 286 - Time elapsed: 1.1697461605072021
# Iteration 287 - Time elapsed: 1.1517741680145264
# Iteration 288 - Time elapsed: 1.1521599292755127
# Iteration 289 - Time elapsed: 1.161705732345581
# Iteration 290 - Time elapsed: 1.1606626510620117
# Iteration 291 - Time elapsed: 1.157055377960205
# Iteration 292 - Time elapsed: 1.1619195938110352
# Iteration 293 - Time elapsed: 1.142880916595459
# Iteration 294 - Time elapsed: 1.1598553657531738
# Iteration 295 - Time elapsed: 1.1600062847137451
# Iteration 296 - Time elapsed: 1.1619389057159424
# Iteration 297 - Time elapsed: 1.1559715270996094
# Iteration 298 - Time elapsed: 1.1578104496002197
# Iteration 299 - Time elapsed: 1.1604671478271484
# Iteration 300 - Time elapsed: 1.1613872051239014
# Current Iteration: 300
# tracks/Vulture of Fire.mp3
# Real Track: [[0.9995709]]
# Fake Track: [[0.355905]]
# White Noise: [[9.1897315e-14]]
# Mon Jan 31 23:04:51 2022
# Iteration 301 - Time elapsed: 0.0049991607666015625
# Iteration 302 - Time elapsed: 0.005997657775878906
# Iteration 303 - Time elapsed: 0.004998683929443359
# Iteration 304 - Time elapsed: 0.005998134613037109
# Iteration 305 - Time elapsed: 0.004998207092285156
# Iteration 306 - Time elapsed: 0.004998683929443359
# Iteration 307 - Time elapsed: 0.004998207092285156
# Iteration 308 - Time elapsed: 0.004997968673706055
# Iteration 309 - Time elapsed: 0.003998994827270508
# Iteration 310 - Time elapsed: 0.003998279571533203
# Iteration 311 - Time elapsed: 0.004998207092285156
# Iteration 312 - Time elapsed: 0.4137279987335205
# Iteration 313 - Time elapsed: 1.1602692604064941
# Iteration 314 - Time elapsed: 1.151576280593872
# Iteration 315 - Time elapsed: 1.1639676094055176
# Iteration 316 - Time elapsed: 1.1582190990447998
# Iteration 317 - Time elapsed: 1.1554827690124512
# Iteration 318 - Time elapsed: 1.154731273651123
# Iteration 319 - Time elapsed: 1.1639823913574219
# Iteration 320 - Time elapsed: 1.150649070739746
# Iteration 321 - Time elapsed: 1.160710334777832
# Iteration 322 - Time elapsed: 1.1580512523651123
# Iteration 323 - Time elapsed: 1.158827543258667
# Iteration 324 - Time elapsed: 1.1642084121704102
# Iteration 325 - Time elapsed: 1.1308088302612305
# Iteration 326 - Time elapsed: 1.1824936866760254
# Iteration 327 - Time elapsed: 3.78800630569458
# Iteration 328 - Time elapsed: 2.6721887588500977
# Iteration 329 - Time elapsed: 1.9923515319824219
# Iteration 330 - Time elapsed: 1.1537392139434814
# Iteration 331 - Time elapsed: 1.151578664779663
# Iteration 332 - Time elapsed: 1.1521689891815186
# Iteration 333 - Time elapsed: 1.1586496829986572
# Iteration 334 - Time elapsed: 1.1566715240478516
# Iteration 335 - Time elapsed: 1.157405138015747
# Iteration 336 - Time elapsed: 1.1540014743804932
# Iteration 337 - Time elapsed: 1.154811143875122
# Iteration 338 - Time elapsed: 1.1486754417419434
# Iteration 339 - Time elapsed: 1.1541814804077148
# Iteration 340 - Time elapsed: 1.1592905521392822
# Iteration 341 - Time elapsed: 1.1558730602264404
# Iteration 342 - Time elapsed: 1.1631355285644531
# Iteration 343 - Time elapsed: 1.1435012817382812
# Iteration 344 - Time elapsed: 1.1569664478302002
# Iteration 345 - Time elapsed: 1.1534433364868164
# Iteration 346 - Time elapsed: 1.1546757221221924
# Iteration 347 - Time elapsed: 1.153111219406128
# Iteration 348 - Time elapsed: 1.1553969383239746
# Iteration 349 - Time elapsed: 1.155322790145874
# Iteration 350 - Time elapsed: 1.1552002429962158
# Current Iteration: 350
# tracks/Ravenlord.mp3
# Real Track: [[0.9624344]]
# Fake Track: [[0.274808]]
# White Noise: [[6.262156e-18]]
# Mon Jan 31 23:05:55 2022
# Iteration 351 - Time elapsed: 0.0049991607666015625
# Iteration 352 - Time elapsed: 0.004997730255126953
# Iteration 353 - Time elapsed: 0.004998922348022461
# Iteration 354 - Time elapsed: 0.005997657775878906
# Iteration 355 - Time elapsed: 0.004998207092285156
# Iteration 356 - Time elapsed: 0.004998445510864258
# Iteration 357 - Time elapsed: 0.004998445510864258
# Iteration 358 - Time elapsed: 0.004998683929443359
# Iteration 359 - Time elapsed: 0.004997968673706055
# Iteration 360 - Time elapsed: 0.0049991607666015625
# Iteration 361 - Time elapsed: 0.004997968673706055
# Iteration 362 - Time elapsed: 0.4136030673980713
# Iteration 363 - Time elapsed: 1.1607420444488525
# Iteration 364 - Time elapsed: 1.1519405841827393
# Iteration 365 - Time elapsed: 1.1593880653381348
# Iteration 366 - Time elapsed: 1.1591918468475342
# Iteration 367 - Time elapsed: 1.1567761898040771
# Iteration 368 - Time elapsed: 1.1597840785980225
# Iteration 369 - Time elapsed: 1.138650894165039
# Iteration 370 - Time elapsed: 1.1558842658996582
# Iteration 371 - Time elapsed: 1.1533327102661133
# Iteration 372 - Time elapsed: 1.1564650535583496
# Iteration 373 - Time elapsed: 1.1573777198791504
# Iteration 374 - Time elapsed: 1.1536977291107178
# Iteration 375 - Time elapsed: 1.1573526859283447
# Iteration 376 - Time elapsed: 1.1585352420806885
# Iteration 377 - Time elapsed: 1.1394240856170654
# Iteration 378 - Time elapsed: 1.163893222808838
# Iteration 379 - Time elapsed: 1.154332160949707
# Iteration 380 - Time elapsed: 1.1545140743255615
# Iteration 381 - Time elapsed: 1.153825044631958
# Iteration 382 - Time elapsed: 1.1587903499603271
# Iteration 383 - Time elapsed: 1.1574249267578125
# Iteration 384 - Time elapsed: 1.156153917312622
# Iteration 385 - Time elapsed: 1.153352975845337
# Iteration 386 - Time elapsed: 1.140641689300537
# Iteration 387 - Time elapsed: 1.1658129692077637
# Iteration 388 - Time elapsed: 1.140622615814209
# Iteration 389 - Time elapsed: 1.1554696559906006
# Iteration 390 - Time elapsed: 1.1578178405761719
# Iteration 391 - Time elapsed: 1.1591448783874512
# Iteration 392 - Time elapsed: 1.1598010063171387
# Iteration 393 - Time elapsed: 1.146618366241455
# Iteration 394 - Time elapsed: 1.159440040588379
# Iteration 395 - Time elapsed: 1.1552441120147705
# Iteration 396 - Time elapsed: 1.1544842720031738
# Iteration 397 - Time elapsed: 1.1449034214019775
# Iteration 398 - Time elapsed: 1.165088176727295
# Iteration 399 - Time elapsed: 1.1414515972137451
# Iteration 400 - Time elapsed: 1.1566145420074463
# Current Iteration: 400
# tracks/Father Save Me.mp3
# Real Track: [[0.00027864]]
# Fake Track: [[0.15848334]]
# White Noise: [[1.5688463e-22]]
# Mon Jan 31 23:06:54 2022
# Iteration 401 - Time elapsed: 0.0059986114501953125
# Iteration 402 - Time elapsed: 0.005997419357299805
# Iteration 403 - Time elapsed: 0.004998683929443359
# Iteration 404 - Time elapsed: 0.005998134613037109
# Iteration 405 - Time elapsed: 0.004998683929443359
# Iteration 406 - Time elapsed: 0.004998445510864258
# Iteration 407 - Time elapsed: 0.005997896194458008
# Iteration 408 - Time elapsed: 0.005997657775878906
# Iteration 409 - Time elapsed: 0.004998922348022461
# Iteration 410 - Time elapsed: 0.004995584487915039
# Iteration 411 - Time elapsed: 0.005998849868774414
# Iteration 412 - Time elapsed: 0.41198277473449707
# Iteration 413 - Time elapsed: 1.1510703563690186
# Iteration 414 - Time elapsed: 1.1600682735443115
# Iteration 415 - Time elapsed: 1.1578314304351807
# Iteration 416 - Time elapsed: 1.141343593597412
# Iteration 417 - Time elapsed: 1.1543760299682617
# Iteration 418 - Time elapsed: 1.1689975261688232
# Iteration 419 - Time elapsed: 1.1548187732696533
# Iteration 420 - Time elapsed: 1.1451857089996338
# Iteration 421 - Time elapsed: 1.151921033859253
# Iteration 422 - Time elapsed: 1.1540477275848389
# Iteration 423 - Time elapsed: 1.1528193950653076
# Iteration 424 - Time elapsed: 1.1610362529754639
# Iteration 425 - Time elapsed: 1.1562764644622803
# Iteration 426 - Time elapsed: 1.1506657600402832
# Iteration 427 - Time elapsed: 1.1565766334533691
# Iteration 428 - Time elapsed: 1.1550111770629883
# Iteration 429 - Time elapsed: 1.154646873474121
# Iteration 430 - Time elapsed: 1.1594557762145996
# Iteration 431 - Time elapsed: 1.1559207439422607
# Iteration 432 - Time elapsed: 1.1467444896697998
# Iteration 433 - Time elapsed: 1.153111219406128
# Iteration 434 - Time elapsed: 1.1531903743743896
# Iteration 435 - Time elapsed: 1.1585068702697754
# Iteration 436 - Time elapsed: 1.1651256084442139
# Iteration 437 - Time elapsed: 1.1442835330963135
# Iteration 438 - Time elapsed: 1.1567418575286865
# Iteration 439 - Time elapsed: 1.1550703048706055
# Iteration 440 - Time elapsed: 1.1554462909698486
# Iteration 441 - Time elapsed: 1.1539833545684814
# Iteration 442 - Time elapsed: 1.1400558948516846
# Iteration 443 - Time elapsed: 1.1698696613311768
# Iteration 444 - Time elapsed: 1.1597635746002197
# Iteration 445 - Time elapsed: 1.1581830978393555
# Iteration 446 - Time elapsed: 1.144059181213379
# Iteration 447 - Time elapsed: 1.1532766819000244
# Iteration 448 - Time elapsed: 1.1572282314300537
# Iteration 449 - Time elapsed: 1.1671056747436523
# Iteration 450 - Time elapsed: 1.1430797576904297
# Current Iteration: 450
# tracks/Let's Go Slaughter He-Man (I Wanna Be the Beast-Man in the Masters of the Universe).mp3
# Real Track: [[6.22056e-05]]
# Fake Track: [[0.06491623]]
# White Noise: [[1.4381584e-26]]
# Mon Jan 31 23:07:54 2022
# Iteration 451 - Time elapsed: 0.0059986114501953125
# Iteration 452 - Time elapsed: 0.005998134613037109
# Iteration 453 - Time elapsed: 0.004998683929443359
# Iteration 454 - Time elapsed: 0.004998207092285156
# Iteration 455 - Time elapsed: 0.005997896194458008
# Iteration 456 - Time elapsed: 0.005998134613037109
# Iteration 457 - Time elapsed: 0.004998207092285156
# Iteration 458 - Time elapsed: 0.004998922348022461
# Iteration 459 - Time elapsed: 0.004998445510864258
# Iteration 460 - Time elapsed: 0.004998683929443359
# Iteration 461 - Time elapsed: 0.004997968673706055
# Iteration 462 - Time elapsed: 0.4087255001068115
# Iteration 463 - Time elapsed: 1.1628625392913818
# Iteration 464 - Time elapsed: 1.1588037014007568
# Iteration 465 - Time elapsed: 1.1508500576019287
# Iteration 466 - Time elapsed: 1.1642093658447266
# Iteration 467 - Time elapsed: 1.158179521560669
# Iteration 468 - Time elapsed: 1.159724473953247
# Iteration 469 - Time elapsed: 1.1421749591827393
# Iteration 470 - Time elapsed: 1.153108835220337
# Iteration 471 - Time elapsed: 1.1519532203674316
# Iteration 472 - Time elapsed: 1.1548490524291992
# Iteration 473 - Time elapsed: 1.162193775177002
# Iteration 474 - Time elapsed: 1.1561625003814697
# Iteration 475 - Time elapsed: 1.1540184020996094
# Iteration 476 - Time elapsed: 1.1555864810943604
# Iteration 477 - Time elapsed: 1.1293580532073975
# Iteration 478 - Time elapsed: 1.185624361038208
# Iteration 479 - Time elapsed: 1.1545250415802002
# Iteration 480 - Time elapsed: 1.1424903869628906
# Iteration 481 - Time elapsed: 1.1544551849365234
# Iteration 482 - Time elapsed: 1.1548676490783691
# Iteration 483 - Time elapsed: 1.1555633544921875
# Iteration 484 - Time elapsed: 1.1548750400543213
# Iteration 485 - Time elapsed: 1.1492044925689697
# Iteration 486 - Time elapsed: 1.1614177227020264
# Iteration 487 - Time elapsed: 1.156360149383545
# Iteration 488 - Time elapsed: 1.1552882194519043
# Iteration 489 - Time elapsed: 1.1561410427093506
# Iteration 490 - Time elapsed: 1.1599390506744385
# Iteration 491 - Time elapsed: 1.1549546718597412
# Iteration 492 - Time elapsed: 1.1436936855316162
# Iteration 493 - Time elapsed: 1.1586556434631348
# Iteration 494 - Time elapsed: 1.1555073261260986
# Iteration 495 - Time elapsed: 1.15779709815979
# Iteration 496 - Time elapsed: 1.1535208225250244
# Iteration 497 - Time elapsed: 1.1527619361877441
# Iteration 498 - Time elapsed: 1.155724048614502
# Iteration 499 - Time elapsed: 1.1400351524353027
# Iteration 500 - Time elapsed: 1.162287950515747
# Current Iteration: 500
# tracks/Believe.mp3
# Real Track: [[2.3119696e-06]]
# Fake Track: [[0.0278917]]
# White Noise: [[1.6117157e-29]]
# Mon Jan 31 23:08:53 2022

# %%
noise = np.random.randn(1,41*19)

# %%
noise.shape

# %%
fake_spec = artist.predict(noise)

# %%
fake_spec.shape

# %%
track = spec_2_song(fake_spec[0])

# %%
track.shape[0]/30

# %%
IAudio(track,rate=22033)

# %%
newtrack = continue_sample(real_track[0],num_seconds = 10)

# %%
newtrack = np.array(newtrack).reshape(-1)

# %%
np.where(np.isnan(newtrack))

# %%
faketrack_mean, faketrack_preds = decide_track(np.array(newtrack).reshape(-1))

# %%
faketrack_mean

# %%
soundfile.write('test-denseNN.wav',np.array(newtrack).reshape(-1),samplerate=2**14,format='WAV')

# %%
plt.plot(np.array(newtrack).reshape(-1))

# %%
IAudio(np.array(newtrack[0]).reshape(-1),rate=sr)
